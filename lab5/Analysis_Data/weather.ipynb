# %%
import pandas as pd

df = pd.read_csv('weather.csv', sep=';', header=None)
df
# Out:
#                          0     1     2     3     4     5     6     7     8   \
# 0     MX000017004195504TMAX   310   310   310   320   330   320   320   330
# 1     MX000017004195504TMIN   150   150   160   150   160   160   160   160
# 2     MX000017004195504PRCP     0     0     0     0     0     0     0     0
# 3     MX000017004195505TMAX   310   310   310   300   300   300   310   310
# 4     MX000017004195505TMIN   200   160   160   150   150   150   160   160
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1709  MX000017004201103TMIN -9999 -9999 -9999 -9999   148 -9999 -9999 -9999
# 1710  MX000017004201103PRCP     0 -9999     0     0     0 -9999     0     0
# 1711  MX000017004201104TMAX -9999   350 -9999 -9999 -9999 -9999 -9999 -9999
# 1712  MX000017004201104TMIN -9999   168 -9999 -9999 -9999 -9999 -9999 -9999
# 1713  MX000017004201104PRCP     0     0 -9999 -9999     0     0 -9999 -9999
#
# ...
